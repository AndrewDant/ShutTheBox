# %% [markdown]
# ### Import the game data

# %%
import json

with open('data.json') as json_file:
    data = json.load(json_file)
    
    print(data)
# Out:
# [{'strategy': 'highest_numbers', 'rolls': [4, 6, 2, 5, 12, 8, 9], 'knockdowns': [[4], [6], [2], [5], [3, 9], [8]], 'score': 18}, {'strategy': 'highest_numbers', 'rolls': [5, 9, 7, 7, 6, 9], 'knockdowns': [[5], [9], [7], [1, 6], [2, 4]], 'score': 21}, {'strategy': 'highest_numbers', 'rolls': [6, 5, 3, 6, 6], 'knockdowns': [[6], [5], [3], [2, 4]], 'score': 35}, {'strategy': 'highest_numbers', 'rolls': [11, 8, 6, 9, 10, 2, 4, 1], 'knockdowns': [[1, 10], [8], [6], [9], [3, 7], [2], [4]], 'score': 5}, {'strategy': 'highest_numbers', 'rolls': [5, 4, 3, 9, 8, 8, 2, 2], 'knockdowns': [[5], [4], [3], [9], [8], [1, 7], [2]], 'score': 16}, {'strategy': 'highest_numbers', 'rolls': [7, 2, 9, 6, 6, 6], 'knockdowns': [[7], [2], [9], [6], [1, 5]], 'score': 25}, {'strategy': 'highest_numbers', 'rolls': [5, 5, 10, 11, 3, 9], 'knockdowns': [[5], [1, 4], [10], [2, 9], [3]], 'score': 21}, {'strategy': 'highest_numbers', 'rolls': [7, 9, 11, 5, 3, 5], 'knockdowns': [[7], [9], [1, 10], [5], [3]], 'score': 2
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#                              strategy                       rolls  \
# 0                     highest_numbers      [4, 6, 2, 5, 12, 8, 9]
# 1                     highest_numbers          [5, 9, 7, 7, 6, 9]
# 2                     highest_numbers             [6, 5, 3, 6, 6]
# 3                     highest_numbers  [11, 8, 6, 9, 10, 2, 4, 1]
# 4                     highest_numbers    [5, 4, 3, 9, 8, 8, 2, 2]
# ..                                ...                         ...
# 295  preserve_double_until_10_is_down             [7, 4, 4, 9, 4]
# 296  preserve_double_until_10_is_down      [11, 7, 9, 8, 5, 2, 5]
# 297  preserve_double_until_10_is_down      [8, 6, 5, 7, 7, 11, 7]
# 298  preserve_double_until_10_is_down       [8, 4, 7, 5, 5, 9, 2]
# 299  preserve_double_until_10_is_down     [10, 7, 5, 4, 8, 7, 10]
#
#                                      knockdowns  score
# 0             [[4], [6], [2], [5], [3, 9], [8]]     18
# 1               [[5], [9], [7], [1, 6], [2, 4]]     21
# ...
